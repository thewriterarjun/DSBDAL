# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Student_Academic.csv")

# %%
df.head()
# Out:
#     math  writing  reading  gender  club_join_year
# 0    5.0     28.0     24.0    MALE          2000.0
# 1   95.0     28.0     84.0  FEMALE          2013.0
# 2   45.0     37.0     65.0  FEMALE          2018.0
# 3  500.0      NaN     49.0    MALE          2029.0
# 4   50.0     43.0    700.0  FEMALE          2005.0

# %%
df.isnull().sum()
# Out:
# math              1
# writing           2
# reading           1
# gender            0
# club_join_year    1
# dtype: int64

# %%
df['math']=df['math'].fillna(df['math'].mean())

# %%
df.columns
# Out:
# Index(['math', 'writing', 'reading', 'gender', 'club_join_year'], dtype='object')

# %%
cols = ['math', 'writing', 'reading', 'club_join_year']

# %%
df[cols] = df[cols].fillna(df[cols].mean())

# %%
df
# Out:
#            math    writing     reading  gender  club_join_year
# 0      5.000000  28.000000   24.000000    MALE     2000.000000
# 1     95.000000  28.000000   84.000000  FEMALE     2013.000000
# 2     45.000000  37.000000   65.000000  FEMALE     2018.000000
# 3    500.000000  35.117647   49.000000    MALE     2029.000000
# 4     50.000000  43.000000  700.000000  FEMALE     2005.000000
# 5     29.000000  34.000000   86.000000    MALE     2015.000000
# 6     41.000000  29.000000   29.000000  FEMALE     1993.000000
# 7     15.000000  33.000000   71.000000  FEMALE     2011.611111
# 8     75.000000  45.000000   69.000000    MALE     2025.000000
# 9     17.000000  35.117647   17.000000    MALE     2018.000000
# 10    44.000000  90.000000   86.000000  FEMALE     2012.000000
# 11     4.000000  26.000000   95.000000    MALE     2000.000000
# 12    31.000000  19.000000   33.000000  FEMALE     2008.000000
# 13   179.444444  34.000000   98.000000  FEMALE     2002.000000
# 14  2000.000000  17.000000   96.555556    MALE     2022.000000
# 15    95.000000  46.000000   78.000000  FEMALE     1994.000000
# 16    12.000000  43.000000   26.000000  FEMALE     2018.000000
# 17    98.000000  27.000000  105.000000    MALE     2024.000000
# 18    74.000000  18.000000   23.000000  FEMALE     2013.000000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['gender']=le.fit_transform(df['gender'])

# %%
df.head()
# Out:
#     math    writing  reading  gender  club_join_year
# 0    5.0  28.000000     24.0       1          2000.0
# 1   95.0  28.000000     84.0       0          2013.0
# 2   45.0  37.000000     65.0       0          2018.0
# 3  500.0  35.117647     49.0       1          2029.0
# 4   50.0  43.000000    700.0       0          2005.0

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
plt.show()

# %%
Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3 - Q1

df[cols] = df[cols].clip(Q1 - 1.5*IQR, Q3 + 1.5*IQR, axis=1)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMa
